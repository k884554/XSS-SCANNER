# %%
from predict_without_space import predict_wos

P = predict_wos("<html,>,<head,>,<meta,/>,<meta,/>,<meta,/>,<title,>,</title>,</head>,<body,>,<script,language=,\",\",>")
P.predict()
# Out:
# ['<html', '>', '<head', '>']
# <html><head>"
# '"">'
