# %%
import sys
from selenium import webdriver
from CheckXSS import check_xss

driver = webdriver.Firefox()

check_xss('http://localhost:8080/xss/reflect/textarea1?in=foo1', driver)
# Out:
# Using TensorFlow backend.
# # of distinct words: 1215
# # of total words: 100797
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 128)               688128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1215)              156735
# _________________________________________________________________
# activation_1 (Activation)    (None, 1215)              0
# ...
# Total params: 844,863
# Trainable params: 844,863
# Non-trainable params: 0
# _________________________________________________________________
# ['<body', '>', '<h2', '>', '</h2>', '<p', '>', '<form', '>', '<textarea', 'name=', '"', '"', 'rows=', '"', '"', 'cols=', '"', '"', '>']
# <body><h2></h2><p><form><textareaname=""rows=""cols="">"
# ----- URL     : http://localhost:8080/xss/reflect/textarea1?in=foo1
# ...
